# %%
import os
from PIL import Image
import time
import shutil
from jmcomic import download_album

def webp_to_pdf(folder_path: str, output_pdf: str):
    """
    将文件夹中的webp图片合并为PDF文件。
    :param folder_path: 图片所在的文件夹路径
    :param output_pdf: 输出PDF文件路径
    """
    images = []
    for file_name in sorted(os.listdir(folder_path)):
        file_path = os.path.join(folder_path, file_name)
        if file_name.lower().endswith('.webp'):
            with Image.open(file_path) as img:
                images.append(img.convert("RGB"))

    if images:
        images[0].save(output_pdf, save_all=True, append_images=images[1:])

def safe_remove(file_path: str):
    """
    安全删除文件，确保文件未被占用。
    :param file_path: 要删除的文件路径
    """
    for _ in range(5):
        try:
            if os.path.exists(file_path):
                os.remove(file_path)
            break
        except PermissionError:
            time.sleep(1)

def find_target_folders(directory: str) -> list:
    """
    在指定目录中找到所有目标文件夹，忽略指定的文件夹。
    :param directory: 要扫描的目录路径
    :return: 目标文件夹的路径列表
    """
    ignored_folders = {"__pycache__", ".venv", "JMComic", "Lagrange.OneBot", "src"}
    folders = [
        os.path.join(directory, f)
        for f in os.listdir(directory)
        if os.path.isdir(os.path.join(directory, f)) and f not in ignored_folders
    ]
    return folders

def download_and_convert_to_pdf(album_id: str):
    """
    下载漫画并将其转换为PDF文件。
    :param album_id: 漫画ID
    """
    try:
        # Step 1: 下载漫画
        print(f"正在下载漫画ID: {album_id}...")
        download_album(album_id)

        # Step 2: 查找下载后的文件夹
        folder_paths = find_target_folders(os.getcwd())
        if not folder_paths:
            print("未找到有效的文件夹，请检查下载是否成功。")
            return

        # Step 3: 转换为PDF并保存
        for folder_path in folder_paths:
            output_pdf = f"{folder_path}.pdf"
            try:
                webp_to_pdf(folder_path, output_pdf)

                if os.path.exists(output_pdf):
                    print(f"PDF已成功生成: {output_pdf}")
                else:
                    print(f"文件夹 {os.path.basename(folder_path)} 的 PDF 生成失败。")
            except Exception as e:
                print(f"处理文件夹 {os.path.basename(folder_path)} 时发生错误：{str(e)}")
            finally:
                if os.path.exists(folder_path):
                    shutil.rmtree(folder_path)

    except Exception as e:
        print(f"发生错误：{str(e)}")

# 示例：输入漫画ID，下载并转换为PDF
album_id = input("请输入漫画ID：")
download_and_convert_to_pdf(album_id)
# Out:
# 正在下载漫画ID: 114514...
# [2025-03-24 18:15:39] [MainThread]:【api】https://www.jmapiproxyxxx.vip/album?id=114514
# [2025-03-24 18:15:40] [MainThread]:【album.before】本子获取成功: [114514], 作者: [default_author], 章节数: [1], 总页数: [0], 标题: [[怪奇日蝕(綾野なおと)][Bitter100％]], 关键词: ['怪奇日蝕']
# [2025-03-24 18:15:40] [Thread-59 (<lambda>)]:【api】https://www.jmapiproxyxxx.vip/chapter?id=114514
# [2025-03-24 18:15:41] [Thread-59 (<lambda>)]:【photo.before】开始下载章节: 114514 (114514[1/1]), 标题: [[怪奇日蝕(綾野なおと)][Bitter100％]], 图片数为[27]
# [2025-03-24 18:15:41] [Thread-60 (<lambda>)]:【image.before】图片准备下载: 114514/00001.webp [1/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00001.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00001.webp]
# [2025-03-24 18:15:41] [Thread-63 (<lambda>)]:【image.before】图片准备下载: 114514/00004.webp [4/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00004.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00004.webp]
# [2025-03-24 18:15:41] [Thread-61 (<lambda>)]:【image.before】图片准备下载: 114514/00002.webp [2/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00002.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00002.webp]
# [2025-03-24 18:15:41] [Thread-65 (<lambda>)]:【image.before】图片准备下载: 114514/00006.webp [6/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00006.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00006.webp]
# [2025-03-24 18:15:41] [Thread-79 (<lambda>)]:【image.before】图片准备下载: 114514/00020.webp [20/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00020.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00020.webp]
# [2025-03-24 18:15:41] [Thread-66 (<lambda>)]:【image.before】图片准备下载: 114514/00007.webp [7/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00007.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00007.webp]
# [2025-03-24 18:15:41] [Thread-62 (<lambda>)]:【image.before】图片准备下载: 114514/00003.webp [3/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00003.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00003.webp]
# [2025-03-24 18:15:41] [Thread-67 (<lambda>)]:【image.before】图片准备下载: 114514/00008.webp [8/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00008.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00008.webp]
# [2025-03-24 18:15:41] [Thread-74 (<lambda>)]:【image.before】图片准备下载: 114514/00015.webp [15/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00015.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00015.webp]
# [2025-03-24 18:15:41] [Thread-75 (<lambda>)]:【image.before】图片准备下载: 114514/00016.webp [16/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00016.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00016.webp]
# [2025-03-24 18:15:41] [Thread-77 (<lambda>)]:【image.before】图片准备下载: 114514/00018.webp [18/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00018.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00018.webp]
# [2025-03-24 18:15:41] [Thread-64 (<lambda>)]:【image.before】图片准备下载: 114514/00005.webp [5/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00005.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00005.webp]
# [2025-03-24 18:15:41] [Thread-69 (<lambda>)]:【image.before】图片准备下载: 114514/00010.webp [10/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00010.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00010.webp]
# [2025-03-24 18:15:41] [Thread-68 (<lambda>)]:【image.before】图片准备下载: 114514/00009.webp [9/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00009.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00009.webp]
# [2025-03-24 18:15:41] [Thread-78 (<lambda>)]:【image.before】图片准备下载: 114514/00019.webp [19/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00019.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00019.webp]
# [2025-03-24 18:15:41] [Thread-71 (<lambda>)]:【image.before】图片准备下载: 114514/00012.webp [12/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00012.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00012.webp]
# [2025-03-24 18:15:41] [Thread-80 (<lambda>)]:【image.before】图片准备下载: 114514/00021.webp [21/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00021.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00021.webp]
# [2025-03-24 18:15:41] [Thread-83 (<lambda>)]:【image.before】图片准备下载: 114514/00024.webp [24/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00024.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00024.webp]
# [2025-03-24 18:15:41] [Thread-86 (<lambda>)]:【image.before】图片准备下载: 114514/00027.webp [27/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00027.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00027.webp]
# [2025-03-24 18:15:41] [Thread-72 (<lambda>)]:【image.before】图片准备下载: 114514/00013.webp [13/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00013.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00013.webp]
# [2025-03-24 18:15:41] [Thread-73 (<lambda>)]:【image.before】图片准备下载: 114514/00014.webp [14/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00014.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00014.webp]
# [2025-03-24 18:15:41] [Thread-84 (<lambda>)]:【image.before】图片准备下载: 114514/00025.webp [25/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00025.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00025.webp]
# [2025-03-24 18:15:41] [Thread-81 (<lambda>)]:【image.before】图片准备下载: 114514/00022.webp [22/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00022.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00022.webp]
# [2025-03-24 18:15:41] [Thread-82 (<lambda>)]:【image.before】图片准备下载: 114514/00023.webp [23/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00023.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00023.webp]
# [2025-03-24 18:15:41] [Thread-70 (<lambda>)]:【image.before】图片准备下载: 114514/00011.webp [11/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00011.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00011.webp]
# [2025-03-24 18:15:41] [Thread-85 (<lambda>)]:【image.before】图片准备下载: 114514/00026.webp [26/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00026.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00026.webp]
# [2025-03-24 18:15:41] [Thread-76 (<lambda>)]:【image.before】图片准备下载: 114514/00017.webp [17/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00017.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00017.webp]
# [2025-03-24 18:15:42] [Thread-85 (<lambda>)]:【image.after】图片下载完成: 114514/00026.webp [26/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00026.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00026.webp]
# [2025-03-24 18:15:42] [Thread-86 (<lambda>)]:【image.after】图片下载完成: 114514/00027.webp [27/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00027.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00027.webp]
# [2025-03-24 18:15:42] [Thread-60 (<lambda>)]:【image.after】图片下载完成: 114514/00001.webp [1/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00001.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00001.webp]
# [2025-03-24 18:15:42] [Thread-61 (<lambda>)]:【image.after】图片下载完成: 114514/00002.webp [2/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00002.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00002.webp]
# [2025-03-24 18:15:43] [Thread-84 (<lambda>)]:【image.after】图片下载完成: 114514/00025.webp [25/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00025.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00025.webp]
# [2025-03-24 18:15:43] [Thread-66 (<lambda>)]:【image.after】图片下载完成: 114514/00007.webp [7/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00007.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00007.webp]
# [2025-03-24 18:15:43] [Thread-63 (<lambda>)]:【image.after】图片下载完成: 114514/00004.webp [4/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00004.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00004.webp]
# [2025-03-24 18:15:43] [Thread-69 (<lambda>)]:【image.after】图片下载完成: 114514/00010.webp [10/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00010.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00010.webp]
# [2025-03-24 18:15:43] [Thread-68 (<lambda>)]:【image.after】图片下载完成: 114514/00009.webp [9/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00009.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00009.webp]
# [2025-03-24 18:15:43] [Thread-72 (<lambda>)]:【image.after】图片下载完成: 114514/00013.webp [13/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00013.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00013.webp]
# [2025-03-24 18:15:43] [Thread-64 (<lambda>)]:【image.after】图片下载完成: 114514/00005.webp [5/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00005.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00005.webp]
# [2025-03-24 18:15:43] [Thread-79 (<lambda>)]:【image.after】图片下载完成: 114514/00020.webp [20/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00020.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00020.webp]
# [2025-03-24 18:15:43] [Thread-71 (<lambda>)]:【image.after】图片下载完成: 114514/00012.webp [12/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00012.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00012.webp]
# [2025-03-24 18:15:43] [Thread-65 (<lambda>)]:【image.after】图片下载完成: 114514/00006.webp [6/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00006.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00006.webp]
# [2025-03-24 18:15:43] [Thread-73 (<lambda>)]:【image.after】图片下载完成: 114514/00014.webp [14/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00014.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00014.webp]
# [2025-03-24 18:15:43] [Thread-83 (<lambda>)]:【image.after】图片下载完成: 114514/00024.webp [24/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00024.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00024.webp]
# [2025-03-24 18:15:43] [Thread-62 (<lambda>)]:【image.after】图片下载完成: 114514/00003.webp [3/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00003.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]\00003.webp]
# [2025-03-24 18:15:43] [Thread-76 (<lambda>)]:【image.after】图片下载完成: 114514/00017.webp [17/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00017.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00017.webp]
# [2025-03-24 18:15:43] [Thread-67 (<lambda>)]:【image.after】图片下载完成: 114514/00008.webp [8/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00008.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00008.webp]
# [2025-03-24 18:15:43] [Thread-75 (<lambda>)]:【image.after】图片下载完成: 114514/00016.webp [16/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00016.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00016.webp]
# [2025-03-24 18:15:43] [Thread-70 (<lambda>)]:【image.after】图片下载完成: 114514/00011.webp [11/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00011.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00011.webp]
# [2025-03-24 18:15:44] [Thread-80 (<lambda>)]:【image.after】图片下载完成: 114514/00021.webp [21/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00021.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00021.webp]
# [2025-03-24 18:15:44] [Thread-81 (<lambda>)]:【image.after】图片下载完成: 114514/00022.webp [22/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00022.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00022.webp]
# [2025-03-24 18:15:44] [Thread-78 (<lambda>)]:【image.after】图片下载完成: 114514/00019.webp [19/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00019.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00019.webp]
# [2025-03-24 18:15:44] [Thread-74 (<lambda>)]:【image.after】图片下载完成: 114514/00015.webp [15/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00015.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00015.webp]
# [2025-03-24 18:15:44] [Thread-77 (<lambda>)]:【image.after】图片下载完成: 114514/00018.webp [18/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00018.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00018.webp]
# [2025-03-24 18:15:44] [Thread-82 (<lambda>)]:【image.after】图片下载完成: 114514/00023.webp [23/27], [https://cdn-msp3.jmapinodeudzn.net/media/photos/114514/00023.webp] → [d:/qqbot/jmbot/src/plugins/jm/[怪奇日蝕(綾野なおと)][Bitter100％]/00023.webp]
# [2025-03-24 18:15:44] [Thread-59 (<lambda>)]:【photo.after】章节下载完成: [114514] (114514[1/1])
# [2025-03-24 18:15:44] [MainThread]:【album.after】本子下载完成: [114514]
# PDF已成功生成: d:\qqbot\jmbot\src\plugins\jm\[怪奇日蝕(綾野なおと)][Bitter100％].pdf
